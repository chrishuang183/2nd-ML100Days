# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# Ans :
# This data is so important because we can predict the stocks with news and financial market data, and we can become rich.
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# Ans :
# The data based on two sources of data.
# 1.Market data(2007 to present) provided by Intrinio(a company which sells finical data on the internet.)
# 2.News data(2007 to present) provided by Thomson Reuters(Thomson Reuters is one of the world’s most trusted provider of answers, helping professionals make confident decisions and run better businesses.)
#
# 3. 蒐集而來的資料型態為何
# Ans :
# including JSON, Excel, Python, Ruby, R, Java, CSV.
#
# 4. 這組資料想解決的問題如何評估
# Ans :
# Evaluate the price of the stock, so the real-time data is the most important factor. It must be real-time news and 10 years of market data above in order to predict the stocks price. The news correctly is also an important factor.

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# Ans :
# The core of the question is big data. The big data should include customer's favor, such as what kinds of car they like to take, which way they often go, what kinds of service they would like to want.  We can define how to improve performance by carrying more guests as possible as the driver can.
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# Ans :
# Data can be collected from an app on mobile which customers can reserve a car from, customers also can comment it on this app after completing this business.
#
# 3. 蒐集而來的資料型態為何
# Ans :
# Transform big data to csv file format from apps.
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# Ans :
# Depens on data.

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):

    return sum((y-y_hat)**(2))/len(y)
    
    
def mean_absolute_error(y,y_hat):

    return sum(abs(y-y_hat))/len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 206.099
# The Mean absolute error is 11.651
